# %%
import os
import csv

# %%
with open('test.csv') as myFile:
    reader = csv.reader(myFile, quoting=csv.QUOTE_NONE)
    for row in reader:
        row = [row[0],row[2],row[1],str(int(row[0])+int(row[2])+int(row[1]))]
        print(row)
        with open('test_new.csv','a') as myNewFile:
            writer = csv.writer(myNewFile)
            writer.writerow(row)
            #print (row[1])
# Out:
# ['1', '3', '2', '6']
# ['1', '2', '3', '6']

# %%
with open('airpot.csv') as data:
    reader = csv.reader(data)

    for row in reader:
        if (row[3] == "Australia") or (row[3] == "Russia"):
            print (row[1:])
# Out:
# ['Yakutsk Airport', 'Yakutsk', 'Russia', 'YKS', 'UEEE', '62.093299865722656', '129.77099609375', '325', '9', 'N', 'Asia/Yakutsk', 'airport', 'OurAirports']
# ['Mirny Airport', 'Mirnyj', 'Russia', 'MJZ', 'UERR', '62.534698486328125', '114.03900146484375', '1156', '9', 'N', 'Asia/Yakutsk', 'airport', 'OurAirports']
# ['Ignatyevo Airport', 'Blagoveschensk', 'Russia', 'BQS', 'UHBB', '50.42539978027344', '127.41200256347656', '638', '9', 'N', 'Asia/Yakutsk', 'airport', 'OurAirports']
# ['Khabarovsk-Novy Airport', 'Khabarovsk', 'Russia', 'KHV', 'UHHH', '48.52799987793', '135.18800354004', '244', '10', 'N', 'Asia/Vladivostok', 'airport', 'OurAirports']
# ['Provideniya Bay Airport', 'Provideniya Bay', 'Russia', 'PVS', 'UHMD', '64.37809753417969', '-173.2429962158203', '72', '12', 'N', 'Asia/Anadyr', 'airport', 'OurAirports']
# ['Sokol Airport', 'Magadan', 'Russia', 'GDX', 'UHMM', '59.9109992980957', '150.72000122070312', '574', '11', 'N', 'Asia/Srednekolymsk', 'airport', 'OurAirports']
# ...

# %%
airport_latitudes = {}
airport_longtitudes = {}
with open('airpot.csv') as data:
    reader = csv.reader(data)

    #for row in reader:
        #airport_latitudes[row[0]] = row[7]
    
    #data.seek(0)
    for row in reader:
        airport_latitudes[row[0]] = row[6]

    
print airport_latitudes
# Out:
# {'5989': '21.21100044', '6797': '47.3849983215', '6794': '-31.8885993958', '6795': '48.13570022583008', '6792': '-29.7593994140625', '6793': '-33.3816986084', '6790': '34.86920166015625', '6791': '13.361000061035156', '6798': '53.053890228271484', '6799': '48.446389', '270': '12.047599792480469', '271': '11.855299949645996', '272': '7.7038798332214355', '273': '6.5773701667785645', '274': '9.652170181274414', '275': '5.0154900550842285', '276': '12.916299819946289', '277': '9.257550239562988', '278': '11.130200386047363', '279': '13.5024995803833', '12019': '-34.6239013671875', '12018': '-36.18280029296875', '12015': '-29.973899841308594', '12014': '-34.623600006103516', '12017': '-35.99470138549805', '12016': '-33.70970153808594', '12011': '-23.646099', '12010': '52.297316667', '12013': '-36.55189895629883', '12012': '-37.30939865112305', '9528': '1.04278004169', '9255': '59.397499', '9252': '29.1086006165', '9253': '49.97439956665039', '9251': '38.72140121', '3519': '36.668598175',
# ...

# %%
print (airport_longtitudes)
# Out:
# {}
